# %% [markdown]
# <a href="https://colab.research.google.com/github/HebSODev/TesteEstadiosMongoDB/blob/main/ExemploEstadios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.10.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.7.0)

# %%
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv"

# %%
estadios_df = pd.read_csv(dataset)

# %%
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
dicionario = estadios_df.to_dict('records')

# %%
cliente = MongoClient("mongodb+srv://aulaHebert:1234@cluster0.wonif.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

# %%
db = cliente.get_database('Futebol')

# %%
db.Estadios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('671c47a17abdec20fe8d6f77'), ObjectId('671c47a17abdec20fe8d6f78'), ObjectId('671c47a17abdec20fe8d6f79'), ObjectId('671c47a17abdec20fe8d6f7a'), ObjectId('671c47a17abdec20fe8d6f7b'), ObjectId('671c47a17abdec20fe8d6f7c'), ObjectId('671c47a17abdec20fe8d6f7d'), ObjectId('671c47a17abdec20fe8d6f7e'), ObjectId('671c47a17abdec20fe8d6f7f'), ObjectId('671c47a17abdec20fe8d6f80'), ObjectId('671c47a17abdec20fe8d6f81'), ObjectId('671c47a17abdec20fe8d6f82'), ObjectId('671c47a17abdec20fe8d6f83'), ObjectId('671c47a17abdec20fe8d6f84'), ObjectId('671c47a17abdec20fe8d6f85'), ObjectId('671c47a17abdec20fe8d6f86'), ObjectId('671c47a17abdec20fe8d6f87'), ObjectId('671c47a17abdec20fe8d6f88'), ObjectId('671c47a17abdec20fe8d6f89'), ObjectId('671c47a17abdec20fe8d6f8a')], acknowledged=True)

# %%
estadios = db.Estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-00.wonif.mongodb.net:27017', 'cluster0-shard-00-01.wonif.mongodb.net:27017', 'cluster0-shard-00-02.wonif.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-w8og00-shard-0', tls=True), 'Futebol'), 'Estadios')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('671c47a17abdec20fe8d6f77'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f78'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f79'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f7a'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f7b'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f7c'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f7d'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f7e'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f7f'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f80'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f81'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f82'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f83'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f84'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f85'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f86'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f87'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f88'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f89'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('671c47a17abdec20fe8d6f8a'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
center_lat = -14.24007
center_lon = -53.18050

# %%
consulta = list(estadios.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id           671c47a17abdec20fe8d6f77
# nome                          Maracanã
# capacidade                       78838
# latitude                     -22.90981
# longitude                    -43.23391
# Name: 0, dtype: object

# %%
locationmap = folium.Map(location=[center_lat, center_lon], zoom_start=5, width=800,height = 600)

# %%
qtde = len(df_convertido)
qtde
# Out:
# 20

# %%
for i in range(qtde):
    lng = float(df_convertido.iloc[i]['longitude'])
    lat = float(df_convertido.iloc[i]['latitude'])
    description = 'Estádio: ' + str(df_convertido.iloc[i]['nome'])+'<br> Capacidade: ' +str(df_convertido.iloc[i]['capacidade'])
    folium.Marker([lat, lng],
                  popup = description,
                  icon = folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_717bf69b64e5e2674ea09170bdf7639d {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_717bf69b64e5e2674ea09170bdf7639d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_717bf69b64e5e2674ea09170bdf7639d = L.map(
#                 &quot;map_717bf69b64e5e2674ea09170bdf7639d&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_022f08d6e69cd8bd0c36fc25581d83f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_022f08d6e69cd8bd0c36fc25581d83f8.addTo(map_717bf69b64e5e2674ea09170bdf7639d);
#
#
#             var marker_b3302f72805da8e066b0609fe7e51c5e = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_717bf69b64e5e2674ea09170bdf7639d);
#
#
#             var icon_b74d5b9d88fea26d1ef64d6ca16af00e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b3302f72805da8e066b0609fe7e51c5e.setIcon(icon_b74d5b9d88fea26d1ef64d6ca16af00e);
#
#
#         var popup_c9cb1e9411e3b56703a18adfefcde226 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a1faf287d2bf0f995f5ce7af99f7966 = $(`&lt;div id=&quot;html_7a1faf287d2bf0f995f5ce7af99f7966&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Maracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_c9cb1e9411e3b56703a18adfefcde226.setContent(html_7a1faf287d2bf0f995f5ce7af99f7966);
#
#
#
#         marker_b3302f72805da8e066b0609fe7e51c5e.bindPopup(popup_c9cb1e9411e3b56703a18adfefcde226)
#         ;
#
#
#
#
#             var marker_710abe83281101d5097105371b9bc5cd = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_717bf69b64e5e2674ea09170bdf7639d);
#
#
#             var icon_106fe62dc91cbd1f2dd31a697094cac4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_710abe83281101d5097105371b9bc5cd.setIcon(icon_106fe62dc91cbd1f2dd31a697094cac4);
#
#
#         var popup_ef1990815bc55e68f44a7618f46f3700 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6a235ecb229112758eb626a07754d7f = $(`&lt;div id=&quot;html_d6a235ecb229112758eb626a07754d7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Mané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_ef1990815bc55e68f44a7618f46f3700.setContent(html_d6a235ecb229112758eb626a07754d7f);
#
#
#
#         marker_710abe83281101d5097105371b9bc5cd.bindPopup(popup_ef1990815bc55e68f44a7618f46f3700)
#         ;
#
#
#
#
#             var marker_198f142c393465ff33cf7db658f31f2a = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_717bf69b64e5e2674ea09170bdf7639d);
#
#
#             var icon_73b30bd0cc03821e484814666146b17f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_198f142c393465ff33cf7db658f31f2a.setIcon(icon_73b30bd0cc03821e484814666146b17f);
#
#
#         var popup_e7cfd6bdad2628fae4b5ac654d9d7df5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d642f54d0b212415dbb925331f0dda4 = $(`&lt;div id=&quot;html_4d642f54d0b212415dbb925331f0dda4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Morumbi&lt;br&gt; Capacidade: 66795&lt;/div&gt;`)[0];
#                 popup_e7cfd6bdad2628fae4b5ac654d9d7df5.setContent(html_4d642f54d0b212415dbb925331f0dda4);
#
#
#
#         marker_198f142c393465ff33cf7db658f31f2a.bindPopup(popup_e7cfd6bdad2628fae4b5ac654d9d7df5)
#         ;
#
#
#
#
#             var marker_69fcea78be6751d916c502e4272812b4 = L.marker(
#                 [-3.80674, -38.52168],
#                 {}
#             ).addTo(map_717bf69b64e5e2674ea09170bdf7639d);
#
#
#             var icon_f8c563f1648fea661b9d1ba69c4c6b78 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate
